# %%
import os
from pathlib import Path
import sys
sys.path.extend(['/home/andrea/Documents/Repositories/cancer_phenotype', '/home/andrea/Documents/Repositories/cancer_phenotype/base'])
import re
import copy
import numpy as np
import imageio
import cv2
from scipy.ndimage import morphology
from scipy.stats import mode
import skimage.morphology
from skimage import measure
from matplotlib import pyplot as plt
from quant import read_annotations, contour_to_mask, get_image_for_contour, annotations_summary, find_overlap, contours_to_multilabel_masks, ContourProcessor
from quant.features import region_properties
from base.datasets.wsi_reader import WSIReader

# %%
slide_id = '17_A047-4463_153D+-+2017-05-11+09.40.22'
annotations_dir = Path('/home/andrea/Documents/Repositories/AIDA/dist')
contour_struct = read_annotations(annotations_dir, (slide_id,))
annotations_summary(contour_struct)
# Out:
# 17_A047-4463_153D+-+2017-05-11+09.40.22_shrunk0.8: epithelium 1518 contours | lumen 560 contours | background 0 contours |
# 17_A047-4463_153D+-+2017-05-11+09.40.22_pre_shrink: epithelium 1518 contours | lumen 560 contours | background 0 contours |
# 17_A047-4463_153D+-+2017-05-11+09.40.22_premerge: epithelium 1518 contours | lumen 560 contours | background 0 contours |
# 17_A047-4463_153D+-+2017-05-11+09.40.22: epithelium 1224 contours | lumen 527 contours | background 0 contours |
# 17_A047-4463_153D+-+2017-05-11+09.40.22_merge_examples: epithelium 86 contours | lumen 69 contours | background 0 contours |
# /home/andrea/Documents/Repositories/cancer_phenotype/base/utils/annotation_builder.py:52: UserWarning: No available metadata for 17_A047-4463_153D+-+2017-05-11+09.40.22_merge_examples
#   warnings.warn(f"No available metadata for {obj['slide_id']}")

# %%
contour_lib = contour_struct['17_A047-4463_153D+-+2017-05-11+09.40.22_premerge']
example = contour_lib['epithelium'][12]
print(example.shape)
print(cv2.boundingRect(example))
# Out:
# (134, 1, 2)
# (28222, 25364, 388, 378)

# %%
mask = contour_to_mask(example)
print(type(mask))
plt.imshow(mask * 255)
print(np.unique(mask))
# Out:
# <class 'numpy.ndarray'>
# [  0. 250.]

# %%
opt = WSIReader.get_reader_options()
slide_path = Path('/home/andrea/Documents/Temp/Data/17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi')
reader = WSIReader(opt, slide_path)

# %%
cv2.boundingRect(example)
# Out:
# (28222, 25364, 388, 378)

# %%
image = get_image_for_contour(example, reader)
plt.imshow(image)
# FIXME why is this suddenly broken ?

# %%
overlap_struct, contours, contour_bbs, labels = find_overlap(contour_lib)
label_values = {'epithelium': 200, 'lumen': 250}
i = next(j for j, overlap_vect in enumerate(overlap_struct) if any(overlap_vect))
masks_gen = contours_to_multilabel_masks(contour_lib, overlap_struct, contour_bbs, label_values, indices=[i])
if any(overlap_struct[i]):
    idx1 = overlap_struct[i].index(True)
    print(labels[idx1])
    fig, axes = plt.subplots(1, 2)
    axes[0].imshow(contour_to_mask(contours[i]))
    axes[1].imshow(contour_to_mask(contours[idx1]))
# Out:
# lumen

# %%
example_multilabel_mask, index = next(masks_gen)  # index was given above, so contour should be the desired one.
print(example_multilabel_mask.shape)
example_image = get_image_for_contour(contours[i], reader)
fig, axes = plt.subplots(1, 2)
axes[0].imshow(example_multilabel_mask)
axes[1].imshow(example_image)
np.unique(example_multilabel_mask)
# Out:
# (277, 360)
# array([  0., 200., 250.])

# %%
# test region props on multilabel mask
print(type(region_properties))
# Out:
# <class 'quant.features.Feature'>

# %%
region_properties(example_multilabel_mask, example_image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-2bdf5136e599> in <module>
# ----> 1 region_properties(example_multilabel_mask, example_image)
#
# ~/Documents/Repositories/cancer_phenotype/quant/features.py in __call__(self, *args, **kwargs)
#      39         if 'image' in self.type_ and not any(self.is_mask(arg) for arg in args):
#      40             raise ValueError(f"Arguments does not contain image-type input (f: {self.name})")
# ---> 41         output = self.function(*args, **kwargs)
#      42         assert len(output) == len(self.returns), "Output must match feature description"
#      43         return output
#
# AttributeError: function

# %%
processor = ContourProcessor(contour_lib, overlap_struct, contour_bbs, label_values, reader)
data_iter = iter(processor)

# %%
data = next(data_iter)

# %%
data[-1]
# Out:
# [(28055, 26326, 361, 278), (26834, 26230, 222, 196)]
