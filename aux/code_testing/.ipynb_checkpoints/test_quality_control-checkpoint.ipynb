# %%
# Test performance of quality control measures on slides
import sys
from pathlib import Path
from itertools import product
import random
from collections import deque
import pytest
import numpy as np
import openslide
import matplotlib.pyplot as plt
import cv2
from skimage.morphology import remove_small_objects
sys.path.extend(['../../', '../../base/', '../../base/options/*', '../../base/data/*'])
import base.data as data
from base.utils import utils
import base.options as options
random.seed(42)

# %%
def wsi_file():
    '''Returns an example WSI file path'''
    if utils.on_cluster():
        return '/well/rittscher/projects/TCGA_prostate/TCGA/ff46403a-5498-4ffa-bf85-73afb558eb95/TCGA-J4-A67R-01Z-00-DX1.833DA729-D98E-44F8-A437-1B5BF52071BD.svs'
    elif sys.platform == 'linux':
        return '/home/sedm5660/Documents/Temp/Data/cancer_phenotype/17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi'
    else:
        return '/Users/andreachatrian/Documents/Temp/Data/cancer_phenotype/17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi'

wsi_file = wsi_file()
assert utils.is_pathname_valid(wsi_file)

# %%
print(sys.argv)
sys.argv = sys.argv[0:1]  # for jupyter notebook, must remove first two entries
sys.argv.extend([
   '--gpu_ids=-1', 
    '--data_dir=/home/sedm5660/Documents/Temp/Data/cancer_phenotype', 
    '--task=phenotype',
    '--mpp=0.5',
    '--qc_mpp=2.0'
])
print(sys.argv)
# Out:
# ['/home/sedm5660/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py', '--gpu_ids=-1', '--data_dir=/home/sedm5660/Documents/Temp/Data/cancer_phenotype', '--task=phenotype', '--mpp=0.5', '--qc_mpp=2.0']
# ['/home/sedm5660/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py', '--gpu_ids=-1', '--data_dir=/home/sedm5660/Documents/Temp/Data/cancer_phenotype', '--task=phenotype', '--mpp=0.5', '--qc_mpp=2.0']

# %%
def apply_options():
    ApplyOptions = options.apply_options.ApplyOptions
    apply_options = ApplyOptions()
    return apply_options
apply_options = apply_options()

# %%
opt = apply_options.parse()
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                   augment: 0
#               augment_dir:
#             augment_level: 0
#                batch_size: 16
#           check_tile_blur: False
#           check_tile_fold: False
#           checkpoints_dir:
#             cna_tablefile: /well/rittscher/projects/TCGA_prostate/TCGA/data/prad_tcga_pan_can_atlas_2018/data_CNA.txt
#                 patch_size: 1024
#                  data_dir: /home/sedm5660/Documents/Temp/Data/cancer_phenotype	[default: /well/rittscher/projects/TCGA_prostate/TCGA]
#               data_fields: case_submitter_id,sample_id,case_id,sample_submitter_id,is_ffpe,sample_type,state,oct_embedded
#              dataset_name: tcga
#             deployer_name: segment
#                deployment: y
#           display_winsize: 256
#                      eval: False
#           experiment_name: experiment_name
#           field_datatypes: text,text,text,text,text,text,text,text
#                 fine_size: 512
#            fork_processes: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#            input_channels: 3
#                  is_train: False                         	[default: None]
#             learning_rate: 0.0001
#    learning_rate_patience: 50
#                load_epoch: latest
#                 load_iter: 0
#                 load_size: 512
#               loss_weight: None
#                  losstype: ce
#              metadata_dir: /well/rittscher/projects/TCGA_prostate/TCGA/data/datacopy
#                     model: Inception
#                       mpp: 0.5                           	[default: 2.0]
#           ndeploy_workers: 1
#                 num_class: 2
#               num_filters: 15
#                     phase: train
#                print_freq: 100
#                    qc_mpp: 2.0                           	[default: 4.0]
#               results_dir: /well/rittscher/users/achatrian/Results/applied
#              sample_index: sample_submitter_id
#       set_visible_devices: True                          	[default: y]
#                      task: phenotype                     	[default: segment]
#                   verbose: False
#              weight_decay: 0.0005
#                   workers: 4
#             wsi_tablefile: /well/rittscher/projects/TCGA_prostate/TCGA/data/biospecimen.project-TCGA-PRAD.2018-10-05/sample.tsv
# ----------------- End -------------------

# %%
#save opt for use in extracting patches
data_dir = opt.data_dir
opt.data_dir = '/well/rittscher/projects/TCGA_prostate/TCGA'
import pickle
with open(Path('/mnt/rescomp/projects/TCGA_prostate/TCGA')/'data'/'opt.pkl', 'wb') as opt_file:
    pickle.dump(opt, opt_file)
opt.data_dir = data_dir
print(opt.data_dir)
# Out:
# /home/sedm5660/Documents/Temp/Data/cancer_phenotype

# %%
slide = data.wsi_reader.WSIReader(opt, wsi_file)

# %%
slide.find_tissue_locations()
for loc, info in random.sample(list(slide.tile_info.items()), k=min(20, len(slide.locations))):
    print(f'{loc} - {info}')
len(slide.locations)
# Out:
# [Errno 2] No such file or directory: '/home/sedm5660/Documents/Temp/Data/cancer_phenotype/data/quality_control/17_A047-4463_153D+-+2017-05-11+09.40.22.tsv'
# 133120,38912 - empty
# 22528,32768 - good
# 4096,45056 - empty
# 153600,75776 - empty
# 57344,12288 - empty
# 51200,6144 - empty
# 45056,69632 - empty
# 28672,22528 - good
# 153600,32768 - empty
# 20480,38912 - empty
# 141312,22528 - empty
# 153600,67584 - empty
# 112640,67584 - good
# 16384,73728 - empty
# 122880,36864 - empty
# 88064,16384 - empty
# 6144,20480 - empty
# 6144,4096 - empty
# 18432,47104 - empty
# 45056,30720 - good
# 3280

# %%
# functions for quality control on histology tiles
def is_HnE_mask(image, threshold=0.5, sat_thresh=30):
    """Returns true if slide contains tissue or just background
    Problem: doesn't work if tile is completely white because of normalization step"""
    hsv_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV).astype(float)
    # do hue and saturation check
    sat_mean = hsv_image[..., 1].mean()
    empirical = hsv_image.prod(axis=2)  # found by Ka Ho to work
    empirical = empirical/np.max(empirical)*255  # found by Ka Ho to work
    kernel = np.ones((20, 20), np.uint8)
    ret, _ = cv2.threshold(empirical.astype(np.uint8), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    mask = cv2.morphologyEx((empirical > ret).astype(np.uint8), cv2.MORPH_CLOSE, kernel)
    mask = remove_small_objects(mask.astype(bool), min_size=image.shape[0]/10)
    return np.logical_and(mask > threshold, np.logical_not(hsv_image[..., 1] < sat_thresh)), empirical, hsv_image

# functions for quality control on histology tiles
def is_HnE(image, threshold=0.5, sat_thresh=30):
    """Returns true if slide contains tissue or just background
    Problem: doesn't work if tile is completely white because of normalization step"""
    hsv_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV).astype(float)
    # saturation check
    sat_mean = hsv_image[..., 1].mean()
    empirical = hsv_image.prod(axis=2)  # found by Ka Ho to work
    empirical = empirical/np.max(empirical)*255  # found by Ka Ho to work
    kernel = np.ones((20, 20), np.uint8)
    ret, _ = cv2.threshold(empirical.astype(np.uint8), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    mask = cv2.morphologyEx((empirical > ret).astype(np.uint8), cv2.MORPH_CLOSE, kernel)
    mask = remove_small_objects(mask.astype(bool), min_size=image.shape[0]/10)
    return mask.mean() > threshold and not sat_mean < sat_thresh

# %%
# Calculate qc parameters for slide
qc_downsample = int(slide.level_downsamples[slide.qc_read_level])
read_downsample = int(slide.level_downsamples[slide.read_level])
qc_stride = slide.opt.patch_size * read_downsample  # size of read tiles at level 0
qc_sizes = (qc_stride // qc_downsample,) * 2  # size of read tiles at level qc_read_level
k = min(len(slide.tissue_locations) - len(slide.tissue_locations)%2, 20)
#loc_sample = random.sample(slide.locations, k)
loc_sample = slide.tissue_locations[:k]
fig, axes = plt.subplots(k//2, 3*2, figsize=(20, 20))
axes = axes.reshape((k, 3))
print(qc_sizes, qc_stride)
tiles, masks, empiricals, hsv_images = deque([],len(loc_sample)), deque([],len(loc_sample)), deque([],len(loc_sample)), deque([],len(loc_sample))
for i, (x, y) in enumerate(loc_sample):
    tile = slide.read_region((x, y), slide.qc_read_level, qc_sizes)
    tile = np.array(tile)
    mask, empirical, hsv_image = is_HnE_mask(tile)
    tiles.append(tile); masks.append(mask); empiricals.append(empirical); hsv_images.append(hsv_image)
    axes[i, 0].imshow(tile)
    axes[i, 1].imshow(mask)
    axes[i, 1].set_title('tissue {:2f}%'.format(mask.mean()))
    axes[i, 2].imshow(empirical)
# Out:
# (256, 256) 2048
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-68f1be391b8b> in <module>()
#      14     tile = slide.read_region((x, y), slide.qc_read_level, qc_sizes)
#      15     tile = np.array(tile)
# ---> 16     mask, empirical, hsv_image = is_HnE_mask(tile)
#      17     tiles.append(tile); masks.append(mask); empiricals.append(empirical); hsv_images.append(hsv_image)
#      18     axes[i, 0].imshow(tile)
#
# NameError: name 'is_HnE_mask' is not defined

# %%
# # Check misclassified
# fig, axes = plt.subplots(1,4)
# idx = 4
# axes[0].imshow(tiles[idx]); axes[1].imshow(masks[idx]); axes[2].imshow(empiricals[idx]); axes[3].imshow(hsv_images[idx])
# print(f'Tile qc result: {is_HnE(tiles[idx], size_wsi=slide.level_dimensions[slide.qc_read_level])}')

# %%
# Show same slides on level 0
k = min(len(slide.tissue_locations) - len(slide.tissue_locations)%2, 20)
#loc_sample = random.sample(slide.locations, k)
loc_sample = slide.tissue_locations[:k]
sizes = (slide.opt.patch_size,) * 2
fig, axes = plt.subplots(k//2, 3*2, figsize=(20, 20))
axes = axes.reshape((k, 3))
tiles, masks, empiricals, hsv_images = deque([],len(loc_sample)), deque([],len(loc_sample)), deque([],len(loc_sample)), deque([],len(loc_sample))
for i, (x, y) in enumerate(loc_sample):
    tile = slide.read_region((x, y), slide.read_level, sizes)
    tile = np.array(tile)
    mask, empirical, hsv_image = is_HnE_mask(tile)
    tiles.append(tile); masks.append(mask); empiricals.append(empirical); hsv_images.append(hsv_image)
    axes[i, 0].imshow(tile)
    axes[i, 1].imshow(mask)
    axes[i, 1].set_title('tissue {:2f}%'.format(mask.mean()))
    axes[i, 2].imshow(empirical)

# %%
openslide.PROPERTY_NAME_BACKGROUND_COLOR
# Out:
# 'openslide.background-color'

# %%
slide.properties
# Out:
# <_PropertyMap {'hamamatsu.AHEX[0]': '7411242AC1036C121834BD0770151838BD066C111C31C109680C102BBD10680D0C2EB90F64110C37B50860120832B50A640B0C2DB5105D01082EB5166C071036B90D640E1C2EB9126C071831BD0F7003242BBD16700A2033BD187901282DC51DC2A8', 'hamamatsu.AHEX[0].fluorescence': '740F2827B4036C111833B1036C131837B10168111833B103640B102BAD0B640B082BA5075C130837A501580F0433A103600B082FA5095903042FA50F68031037A905640B1C2FA90B6803182FAD077000242BB10D7403242FB10D7907242FB50F8D1D', 'hamamatsu.AHEX[0].ploidy': '740F2827B4036C111833B1036C131837B10168111833B103640B102BAD0B640B082BA5075C130837A501580F0433A103600B082FA5095903042FA50F68031037A905640B1C2FA90B6803182FAD077000242BB10D7403242FB10D7907242FB50F8D1D', 'hamamatsu.AHEX[1]': '8012302BC80078142438C1017818243EC50174152833C50470111C32C10874121830BD076C151838BD0368141834B9056C0F1830BD0B6802142FBD12740A2035BD096C142831C10F740B2831C10B7807302DC5127C0C2C33C51480063431C9177FB5', 'hamamatsu.AHEX[1].fluorescence': '8013342BBC0778132837B4037817283BB40574132833B8036C131C2FB1037011142FAC006817143BA80764131037A803680F142FAD036400102FA90974071C37B0006C0F282FB10774072433B5037803302BB5097C09302FB90B8000342FBD0D644C', 'hamamatsu.AHEX[1].ploidy': '8013342BBC0778132837B4037817283BB40574132833B8036C131C2FB1037011142FAC006817143BA80764131037A803680F142FAD036400102FA90974071C37B0006C0F282FB10774072433B5037803302BB5097C09302FB90B8000342FBD0D644C', 'hamamatsu.AHEX[2]': '740F2827B4036C111833B1036C131837B10168111833B103640B102BAD0B640B082BA5075C130837A501580F0433A103600B082FA5095903042FA50F68031037A905640B1C2FA90B6803182FAD077000242BB10D7403242FB10D7907242FB50F8D1D', 'hamamatsu.AHEX[2].fluorescence': '740F2827B4036C111833B1036C131837B10168111833B103640B102BAD0B640B082BA5075C130837A501580F0433A103600B082FA5095903042FA50F68031037A905640B1C2FA90B6803182FAD077000242BB10D7403242FB10D7907242FB50F8D1D', 'hamamatsu.AHEX[2].ploidy': '740F2827B4036C111833B1036C131837B10168111833B103640B102BAD0B640B082BA5075C130837A501580F0433A103600B082FA5095903042FA50F68031037A905640B1C2FA90B6803182FAD077000242BB10D7403242FB10D7907242FB50F8D1D', 'hamamatsu.Created': '2011/04/25', 'hamamatsu.MHLN[0].24bit': '_1357CJIPMKOWYjx', 'hamamatsu.MHLN[0].36bit': '_1357GGEPMKOWYjx', 'hamamatsu.MHLN[1].24bit': '_1357FHHPMKOWYjx', 'hamamatsu.MHLN[1].36bit': '_1359CKJPMKOWYjx', 'hamamatsu.MHLN[2].24bit': '_1357CJIPMKOWYjx', 'hamamatsu.MHLN[2].36bit': '_1357DEEPMKOWYjx', 'hamamatsu.Macro.S/N': '940407', 'hamamatsu.NDP.S/N': '940288', 'hamamatsu.Objective.Lens.Magnificant': '35.16', 'hamamatsu.PSHV': '175', 'hamamatsu.PSHV.10x': '170', 'hamamatsu.PSHV.40x': '175', 'hamamatsu.PSHV.ploidy': '200', 'hamamatsu.PSHV.ploidy.10x': '140', 'hamamatsu.Product': 'C9600-12', 'hamamatsu.Reference': '17_A047-4463_153D', 'hamamatsu.SourceLens': '40', 'hamamatsu.Updated': '2016/01/26', 'hamamatsu.XOffsetFromSlideCentre': '12539363', 'hamamatsu.YOffsetFromSlideCentre': '509804', 'hamamatsu.YRNP[0]': '0,0,0,0', 'hamamatsu.YRNP[1]': '0,0,0,0', 'hamamatsu.YRNP[2]': '0,0,0,0', 'hamamatsu.calibration.version': '248', 'hamamatsu.ccd.height': '0', 'hamamatsu.ccd.width': '9299', 'hamamatsu.ccd.width.ploidy': '9302', 'hamamatsu.coarse.focus.pitch': '4870', 'hamamatsu.colorfilterID': '1', 'hamamatsu.cube.kind': '0', 'hamamatsu.exposure.barcode.macro': '300', 'hamamatsu.exposure.slide.darkfield.macro': '10', 'hamamatsu.exposure.slide.macro': '20', 'hamamatsu.fine.focus.pitch': '250', 'hamamatsu.focalplane.leftbottom': '82748,689945,111498', 'hamamatsu.focalplane.lefttop': '82748,489945,110966', 'hamamatsu.focalplane.rightbottom': '482748,689945,111060', 'hamamatsu.focalplane.righttop': '482748,489945,110527', 'hamamatsu.lane.shift.amount': '4', 'hamamatsu.roi.barcode.macro': '951,334,1215,700', 'hamamatsu.roi.slide.macro': '61,313,1256,722', 'hamamatsu.slant.leftbottom': '86968,690738,111260', 'hamamatsu.slant.lefttop': '86968,490738,110783', 'hamamatsu.slant.rightbottom': '486968,490738,110388', 'hamamatsu.slant.righttop': '486968,690738,110836', 'hamamatsu.slide.tickness': '0', 'hamama ...
