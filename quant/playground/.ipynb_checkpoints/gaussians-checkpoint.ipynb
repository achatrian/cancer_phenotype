# %%
import sys
from pathlib import Path
import numbers
import random
import json
from itertools import chain
print(sys.executable)
sys.path.extend(['..', '../..'])
from tqdm import tqdm_notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FastICA
from sklearn.ensemble import IsolationForest
from sklearn.mixture import GaussianMixture
from skimage import transform, color
import cv2
import imageio
from quant.experiment.clustering import Clustering
from base.data.wsi_reader import WSIReader
# Out:
# /well/rittscher/users/achatrian/.conda/envs/pyenvclone/bin/python

# %%
e = Clustering('guassians',
              ('StandardScaler', 'PCA', 'GaussianMixture'),
              (StandardScaler(), PCA(n_components=5), GaussianMixture(n_components=5)),
              caching_path='/home/andrea/Documents/Temp')

# %%
remove_outliers = True
e.read_data_from_dir('/well/rittscher/projects/prostate-gland-phenotyping/WSI/data/features', max_memory_use=1e10)
if remove_outliers:
    e.remove_outliers()
# Out:
#   5%|▌         | 1/20 [00:07<02:14,  7.06s/it]
# Memory usage: 103230105
#  10%|█         | 2/20 [00:13<02:03,  6.85s/it]
# Memory usage: 167556857
#  15%|█▌        | 3/20 [00:18<01:47,  6.35s/it]
# Memory usage: 186439757
#  20%|██        | 4/20 [00:27<01:53,  7.11s/it]
# Memory usage: 336649387
#  25%|██▌       | 5/20 [00:33<01:42,  6.86s/it]
# Memory usage: 379079200
#  30%|███       | 6/20 [00:39<01:30,  6.49s/it]
# Memory usage: 397222717
#  35%|███▌      | 7/20 [00:45<01:21,  6.31s/it]
# Memory usage: 420541954
#  40%|████      | 8/20 [00:51<01:14,  6.17s/it]
# Memory usage: 433964695
#  45%|████▌     | 9/20 [00:56<01:06,  6.06s/it]
# Memory usage: 439822955
#  50%|█████     | 10/20 [01:03<01:00,  6.08s/it]
# Memory usage: 449605643
#  55%|█████▌    | 11/20 [01:12<01:02,  6.98s/it]
# Memory usage: 563357754
#  60%|██████    | 12/20 [01:20<00:58,  7.30s/it]
# Memory usage: 632291849
#  65%|██████▌   | 13/20 [01:26<00:49,  7.11s/it]
# Memory usage: 640652631
#  70%|███████   | 14/20 [01:34<00:43,  7.28s/it]
# Memory usage: 685868936
#  75%|███████▌  | 15/20 [01:43<00:38,  7.74s/it]
# Memory usage: 760547417
#  80%|████████  | 16/20 [01:51<00:31,  7.87s/it]
# Memory usage: 808380014
#  85%|████████▌ | 17/20 [02:01<00:25,  8.54s/it]
# Memory usage: 921108655
#  90%|█████████ | 18/20 [02:10<00:17,  8.71s/it]
# Memory usage: 981169722
#  95%|█████████▌| 19/20 [02:20<00:09,  9.09s/it]
# Memory usage: 1077062791
# 100%|██████████| 20/20 [02:28<00:00,  8.79s/it]
# Memory usage: 1100381981
# 20 feature files were loaded.
# /well/rittscher/users/achatrian/.conda/envs/pyenvclone/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:214: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# /well/rittscher/users/achatrian/.conda/envs/pyenvclone/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:224: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# /well/rittscher/users/achatrian/.conda/envs/pyenvclone/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:418: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Removed 1935 outliers through IsolationForest(behaviour='old', bootstrap=False, contamination='legacy',
#         max_features=1.0, max_samples='auto', n_estimators=100,
#         n_jobs=None, random_state=None, verbose=0)

# %%
print("Num points ", len(e.x))
print("Num fields ", len(e.x.columns))
print(e.x.index.levels[0])
# Out:
# Num points  17412
# Num fields  7100
# Index(['17_A047-10719_16L+-+2017-05-11+08.56.52',
#        '17_A047-19575_162E+-+2017-05-11+08.34.36',
#        '17_A047-28956_156N+-+2017-05-11+09.57.53',
#        '17_A047-4463_153D+-+2017-05-11+09.40.22',
#        '17_A047-4519_1614P+-+2017-05-11+09.50.49',
#        '17_A047-47800_15J+-+2017-05-11+08.12.44',
#        '17_A047-8544_16J+-+2017-05-11+08.49.27', 'EU_18387_14_1E_HandE',
#        'EU_2248_16_K_H&E', 'EU_26162_16_9x_HandE+-+2017-11-28+11.03.04',
#        'EU_29542_16_1S_HandE+-+2017-11-28+12.49.46',
#        'EU_29797_14_5F_HandE+-+2017-11-28+13.15.48',
#        'EU_30479_16_G_HandE+-+2017-11-28+12.31.57',
#        'EU_30831_14_4D_HandE+-+2017-11-28+11.15.23',
#        'EU_36244_16_9A_HandE+-+2017-11-28+12.41.47',
#        'EU_37106_15_2K_HandE+-+2017-11-28+11.43.55',
#        'EU_38663_17_7G_HandE+-+2017-11-28+11.48.55',
#        'EU_42628_15_4J_HandE+-+2017-11-28+12.20.38',
#        'EU_49057_14_2F_HandE+-+2017-11-28+10.42.55',
#        'EU_52005_15_2I_HandE+-+2017-11-28+11.23.02'],
#       dtype='object')

# %%
e.run()
# Out:
# /well/rittscher/users/achatrian/.conda/envs/pyenvclone/lib/python3.7/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /well/rittscher/users/achatrian/.conda/envs/pyenvclone/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# Total run time: 6.16707444190979s

# %%
e.plot_clusters()#colors=list(str(i * 0.1) for i in range(10)))

# %%
# read in csv file
label_file = '/well/rittscher/projects/prostate-gland-phenotyping/WSI/data/other/TA206_Scores_V2_190718.csv'
labels = pd.read_csv(label_file, sep='\t')
labels = labels.set_index('file_name')

# %%
erg = labels['ERG H Score'].apply(lambda x: int(x) if x.isdigit() else 0)
erg = erg.apply(lambda x: int(x) > 0)
erg = erg.iloc[0::2]  # remove benign samples from spreadseet
erg.index = [s[:-5] for s in erg.index]

# %%
e.x.index.levels[0]
# Out:
# Index(['17_A047-10719_16L+-+2017-05-11+08.56.52',
#        '17_A047-19575_162E+-+2017-05-11+08.34.36',
#        '17_A047-28956_156N+-+2017-05-11+09.57.53',
#        '17_A047-4463_153D+-+2017-05-11+09.40.22',
#        '17_A047-4519_1614P+-+2017-05-11+09.50.49',
#        '17_A047-47800_15J+-+2017-05-11+08.12.44',
#        '17_A047-8544_16J+-+2017-05-11+08.49.27', 'EU_18387_14_1E_HandE',
#        'EU_2248_16_K_H&E', 'EU_26162_16_9x_HandE+-+2017-11-28+11.03.04',
#        'EU_29542_16_1S_HandE+-+2017-11-28+12.49.46',
#        'EU_29797_14_5F_HandE+-+2017-11-28+13.15.48',
#        'EU_30479_16_G_HandE+-+2017-11-28+12.31.57',
#        'EU_30831_14_4D_HandE+-+2017-11-28+11.15.23',
#        'EU_36244_16_9A_HandE+-+2017-11-28+12.41.47',
#        'EU_37106_15_2K_HandE+-+2017-11-28+11.43.55',
#        'EU_38663_17_7G_HandE+-+2017-11-28+11.48.55',
#        'EU_42628_15_4J_HandE+-+2017-11-28+12.20.38',
#        'EU_49057_14_2F_HandE+-+2017-11-28+10.42.55',
#        'EU_52005_15_2I_HandE+-+2017-11-28+11.23.02'],
#       dtype='object')

# %%
erg.index
# Out:
# Index(['EU_29797_14_5F_HandE+-+2017-11-28+13.15.48',
#        'EU_30831_14_4D_HandE+-+2017-11-28+11.15.23', 'EU_2248_16_K_H&E',
#        '17_A047-4519_1614P+-+2017-05-11+09.50.49',
#        'EU_37747_14_5S_HandE+-+2017-11-28+13.04.58',
#        'EU_49057_14_2F_HandE+-+2017-11-28+10.42.55', 'EU_7189_16_2D_HandE',
#        '17_A047-8544_16J+-+2017-05-11+08.49.27',
#        '17_A047-4463_153D+-+2017-05-11+09.40.22',
#        '17_A047-28956_156N+-+2017-05-11+09.57.53',
#        '17_A047-10719_16L+-+2017-05-11+08.56.52',
#        '17_A047-19575_162E+-+2017-05-11+08.34.36',
#        'EU_29769_15_1M_HandE+-+2017-11-28+11.56.21',
#        '17_A047-29957_152D+-+2017-05-11+10.06.25',
#        'EU_26162_16_9x_HandE+-+2017-11-28+11.03.04',
#        'EU_29373_16_1G_HandE+-+2017-11-28+10.25.19',
#        'EU_35928_15_4N_HandE+-+2017-11-28+12.08.09',
#        'EU_37106_15_2K_HandE+-+2017-11-28+11.43.55',
#        'EU_29542_16_1S_HandE+-+2017-11-28+12.49.46',
#        'EU_30479_16_G_HandE+-+2017-11-28+12.31.57',
#        'EU_42619_15_2H_HandE+-+2017-11-28+11.31.12',
#        'EU_42628_15_4J_HandE+-+2017-11-28+12.20.38',
#        'EU_38663_17_7G_HandE+-+2017-11-28+11.48.55', 'EU_18387_14_1E_HandE',
#        '17_A047-47800_15J+-+2017-05-11+08.12.44',
#        'EU_52005_15_2I_HandE+-+2017-11-28+11.23.02',
#        'EU_36244_16_9A_HandE+-+2017-11-28+12.41.47'],
#       dtype='object')

# %%
erg.loc[e.x.index.levels[0][0]]
# Out:
# True

# %%
# plot feature space against ERG:
colors = ['r', 'b']
for slide, erg_v in erg.iteritems():  # erg is a Series
    color_ = colors[int(erg_v)]
    try:
        slide_x = e.x.loc[slide]
        plt.scatter(slide_x.iloc[:, 0], slide_x.iloc[:, 1], color=color_)
    except KeyError:
        pass

# %%
# PTEN
pten = labels['PTEN H Score RESCORE BETTER STAINED TMA'].apply(lambda x: int(x) if x.isdigit() else 0)
pten = pten.apply(lambda x: int(x) > 0)
pten = pten.iloc[0::2]  # remove benign samples from spreadseet
pten.index = [s[:-5] for s in pten.index]

# %%
# plot feature space against ERG:
colors = ['r', 'b']
for slide, pten_v in pten.iteritems():  # erg is a Series
    color_ = colors[int(pten_v)]
    try:
        slide_x = e.x.loc[slide]
        plt.scatter(slide_x.iloc[:, 0], slide_x.iloc[:, 1], color=color_)
    except KeyError:
        pass

# %%
labels
# Out:
#                                                 TMA position Histology number  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi           A1         29797/14
# -                                                         A2         29797/14
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi           A3         30831/14
# -                                                         A4         30831/14
# EU_2248_16_K_H&E.ndpi                                     A6          2248/16
# -                                                         A7          2248/16
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi             A8          4519/16
# -                                                         A9          4519/16
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi           B1         37747/14
# -                                                         B2         37747/14
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi           B3         49057/14
# -                                                         B4         49057/14
# EU_7189_16_2D_HandE.ndpi                                  B6          7186/16
# -                                                         B7          7186/16
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi               B8          8544/16
# -                                                         B9          8544/16
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi              C1          4463/15
# -                                                         C2          4463/15
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi             C3         28956/15
# -                                                         C4         28956/15
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi              C6         10719/16
# -                                                         C7         10719/16
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi             C8         19575/16
# -                                                         C9         19575/16
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi           D1         29769/15
# -                                                         D2         29769/15
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi             D3         29957/15
# -                                                         D4         29957/15
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi           D6         26162/16
# -                                                         D7         26162/16
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi           D8         29373/16
# -                                                         D9         29373/16
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi           E1         35928/15
# -                                                         E2         35928/15
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi           E3         37106/15
# -                                                         E4         37106/15
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi           E6         29542/16
# -                                                         E7         29542/16
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi            E8         30479/16
# -                                                         E9         30479/16
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi           F1         42619/15
# -                                                         F2         42619/15
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi           F3         42628/15
# -                                                         F4         42628/15
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi           F6         38663/17
# -                                                         F7         38663/17
# EU_18387_14_1E_HandE.ndpi                                 F8         18387/14
# -                                                         F9         18387/14
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi              G1         47800/15
# -                                                         G2         47800/15
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi           G3         52002/15
# -                                                         G4         52002/15
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi           G6         36244/16
# -                                                         G7         36244/16
#
#                                                 Tumour / Benign  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi          Tumour
# -                                                        Benign
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi          Tumour
# -                                                        Benign
# EU_2248_16_K_H&E.ndpi                                    Tumour
# -                                                        Benign
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi            Tumour
# -                                                        Benign
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi          Tumour
# -                                                        Benign
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi          Tumour
# -                                                        Benign
# EU_7189_16_2D_HandE.ndpi                                 Tumour
# -                                                        Benign
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi              Tumour
# -                                                        Benign
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi             Tumour
# -                                                        Benign
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi            Tumour
# -                                                        Benign
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi             Tumour
# -                                                        Benign
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi            Tumour
# -                                                        Benign
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi          Tumour
# -                                                        Benign
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi            Tumour
# -                                                        Benign
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi          Tumour
# -                                                        Benign
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi          Tumour
# -                                                        Benign
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi          Tumour
# -                                                        Benign
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi          Tumour
# -                                                        Benign
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi          Tumour
# -                                                        Benign
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi           Tumour
# -                                                        Benign
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi          Tumour
# -                                                        Benign
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi          Tumour
# -                                                        Benign
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi          Tumour
# -                                                        Benign
# EU_18387_14_1E_HandE.ndpi                                Tumour
# -                                                        Benign
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi             Tumour
# -                                                        Benign
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi          Tumour
# -                                                        Benign
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi          Tumour
# -                                                        Benign
#
#                                                 Proliferation index Mib-1 0-100% (only invasive tumour scored, not PIN or intraductal Ca or inflammatory cells. In the benign, only luminal ep cells scored)  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi                                                  0
# -                                                                                                0
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi                                                  0
# -                                                                                                0
# EU_2248_16_K_H&E.ndpi                                                                            1
# -                                                                                                1
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi                                                    1
# -                                                                                                1
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi                                                  0
# -                                                                                                0
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi                                                  0
# -                                                                                                x
# EU_7189_16_2D_HandE.ndpi                                                                         5
# -                                                                                                5
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                                                      x
# -                                                                                                2
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                                                     0
# -                                                                                                0
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                                                    5
# -                                                                                                0
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                                                     1
# -                                                                                                0
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                                                    1
# -                                                                                                0
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi                                                  0
# -                                                                                                0
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                                                    8
# -                                                                                                0
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                                                  0
# -                                                                                                1
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi                                                  5
# -                                                                                                x
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi                                                  0
# -                                                                                                5
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                                                  5
# -                                                                                                0
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                                                  5
# -                                                                                                1
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                                                   5
# -                                                                                                0
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                                                  0
# -                                                                                                1
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                                                  5
# -                                                                                                0
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                                                  0
# -                                                                                                0
# EU_18387_14_1E_HandE.ndpi                                                                        0
# -                                                                                                1
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                                                     1
# -                                                                                                1
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi                                                  5
# -                                                                                                x
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                                                  2
# -                                                                                                0
#
#                                                                       Proliferation index comments  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi                                                NaN
# -                                                                                              NaN
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi                                                NaN
# -                                                                                              NaN
# EU_2248_16_K_H&E.ndpi                                                                          NaN
# -                                                                                              NaN
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi                                                  NaN
# -                                                                                              NaN
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi                                                NaN
# -                                                                                              NaN
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi                                                NaN
# -                                                                                         Drop out
# EU_7189_16_2D_HandE.ndpi                                                                       NaN
# -                                                                                              NaN
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                                      No tumour in core
# -                                                                                              NaN
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                                                   NaN
# -                                                                                              NaN
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                                                  NaN
# -                                                                                              NaN
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                                                   NaN
# -                                                                                              NaN
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                                                  NaN
# -                                                                                              NaN
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi                                                NaN
# -                                                                                              NaN
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                                                  NaN
# -                                                                                              NaN
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                                                NaN
# -                                                                                              NaN
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi                                                NaN
# -                                                                                         Drop out
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi                                                NaN
# -                                                                                              NaN
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                                                NaN
# -                                                                                              NaN
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                                                NaN
# -                                                                                              NaN
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                                                 NaN
# -                                                                                              NaN
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                                                NaN
# -                                                                                              NaN
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                                                NaN
# -                                                                                              NaN
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                                                NaN
# -                                                                                              NaN
# EU_18387_14_1E_HandE.ndpi                                                                      NaN
# -                                                                                              NaN
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                                                   NaN
# -                                                                                              NaN
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi  The intraductal carcinoma component has a high...
# -                                                                     v little epithelium to score
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                                                NaN
# -                                                                                              NaN
#
#                                                 ERG % cells 3+ (H-Score)  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi                        0
# -                                                                      0
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi                        x
# -                                                                      0
# EU_2248_16_K_H&E.ndpi                                                  0
# -                                                                      0
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi                          0
# -                                                                      0
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi                        0
# -                                                                      0
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi                        5
# -                                                                      0
# EU_7189_16_2D_HandE.ndpi                                              90
# -                                                                      0
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                            x
# -                                                                      0
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                           0
# -                                                                      0
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                         10
# -                                                                      0
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                           0
# -                                                                      0
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                          0
# -                                                                      0
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi                        0
# -                                                                      0
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                          0
# -                                                                      0
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                        0
# -                                                                      0
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi                        0
# -                                                                      0
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi                        0
# -                                                                      0
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                        0
# -                                                                      0
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                        0
# -                                                                      0
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                        45
# -                                                                      0
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                        0
# -                                                                      0
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                        0
# -                                                                      0
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                        0
# -                                                                      0
# EU_18387_14_1E_HandE.ndpi                                              0
# -                                                                      0
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                           0
# -                                                                      0
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi                        0
# -                                                                      0
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                        0
# -                                                                      0
#
#                                                 ERG % cells 2+ (H-Score)  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi                        5
# -                                                                      0
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi                        x
# -                                                                      0
# EU_2248_16_K_H&E.ndpi                                                  0
# -                                                                      0
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi                          0
# -                                                                      0
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi                        0
# -                                                                      0
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi                       25
# -                                                                      0
# EU_7189_16_2D_HandE.ndpi                                               5
# -                                                                      0
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                            x
# -                                                                      0
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                          90
# -                                                                      0
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                         80
# -                                                                      0
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                         100
# -                                                                      0
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                          0
# -                                                                      0
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi                        0
# -                                                                      0
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                          0
# -                                                                      0
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                        0
# -                                                                      0
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi                        0
# -                                                                      0
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi                        0
# -                                                                      0
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                        0
# -                                                                      0
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                        0
# -                                                                      0
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                        45
# -                                                                      0
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                       80
# -                                                                      0
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                       90
# -                                                                      0
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                        0
# -                                                                      0
# EU_18387_14_1E_HandE.ndpi                                              0
# -                                                                      0
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                          20
# -                                                                      0
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi                       90
# -                                                                      0
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                        0
# -                                                                      0
#
#                                                 ERG %  cells 1+ (H-Score)  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi                         0
# -                                                                       0
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi                         x
# -                                                                       0
# EU_2248_16_K_H&E.ndpi                                                   0
# -                                                                       0
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi                           0
# -                                                                       0
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi                         0
# -                                                                       0
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi                        50
# -                                                                       0
# EU_7189_16_2D_HandE.ndpi                                                0
# -                                                                       0
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                             x
# -                                                                       0
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                            0
# -                                                                       0
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                           0
# -                                                                       0
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                            0
# -                                                                       0
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                          20
# -                                                                       0
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi                         0
# -                                                                       0
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                           0
# -                                                                       0
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                         0
# -                                                                       0
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi                         0
# -                                                                       0
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi                         0
# -                                                                       0
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                         0
# -                                                                       0
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                         0
# -                                                                       0
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                          0
# -                                                                       0
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                         0
# -                                                                       0
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                         0
# -                                                                       0
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                         0
# -                                                                       0
# EU_18387_14_1E_HandE.ndpi                                               0
# -                                                                       0
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                            0
# -                                                                       0
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi                         0
# -                                                                       0
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                         0
# -                                                                       0
#
#                                                 ERG H Score  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi          10
# -                                                         0
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi           x
# -                                                         0
# EU_2248_16_K_H&E.ndpi                                     0
# -                                                         0
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi             0
# -                                                         0
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi           0
# -                                                         0
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi         115
# -                                                         0
# EU_7189_16_2D_HandE.ndpi                                280
# -                                                         0
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi               x
# -                                                         0
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi            180
# -                                                         0
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi           190
# -                                                         0
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi            200
# -                                                         0
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi            20
# -                                                         0
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi           0
# -                                                         0
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi             0
# -                                                         0
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi           0
# -                                                         0
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi           0
# -                                                         0
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi           0
# -                                                         0
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi           0
# -                                                         0
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi           0
# -                                                         0
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi          225
# -                                                         0
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi         160
# -                                                         0
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi         180
# -                                                         0
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi           0
# -                                                         0
# EU_18387_14_1E_HandE.ndpi                                 0
# -                                                         0
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi             40
# -                                                         0
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi         180
# -                                                         0
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi           0
# -                                                         0
#
#                                                                                 ERG Comments  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi                                          NaN
# -                                                                                        NaN
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi                           No tumour to score
# -                                                                                        NaN
# EU_2248_16_K_H&E.ndpi                                                                    NaN
# -                                                                                        NaN
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi                                            NaN
# -                                                                                        NaN
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi                                          NaN
# -                                                                                        NaN
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi                                          NaN
# -                                                                                        NaN
# EU_7189_16_2D_HandE.ndpi                                                                 NaN
# -                                                                                        NaN
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                                No tumour in core
# -                                                                                        NaN
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                                             NaN
# -                                                                                        NaN
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                                            NaN
# -                                                                                        NaN
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                                             NaN
# -                                                                                        NaN
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                                            NaN
# -                                                                                        NaN
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi                                          NaN
# -                                                                                        NaN
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                                            NaN
# -                                                                                        NaN
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                                          NaN
# -                                                                                        NaN
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi  Only very limited amount of tumour to score
# -                                                                                        NaN
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi                                          NaN
# -                                                                                        NaN
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                                          NaN
# -                                                                                        NaN
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                                          NaN
# -                                                                                        NaN
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                                           NaN
# -                                                                                        NaN
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                                          NaN
# -                                                                                        NaN
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                                          NaN
# -                                                                                        NaN
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                                          NaN
# -                                                                                        NaN
# EU_18387_14_1E_HandE.ndpi                        Only very limited amount of tumour to score
# -                                                                                        NaN
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                                             NaN
# -                                                                                        NaN
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi                                          NaN
# -                                                                                        NaN
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                                          NaN
# -                                                                                        NaN
#
#                                                  ... PTEN % cells 1+   \
# file_name                                        ...
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi  ...                0
# -                                                ...                0
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi  ...                x
# -                                                ...              100
# EU_2248_16_K_H&E.ndpi                            ...                0
# -                                                ...              100
# ...
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                                           x
# -                                                                                   200
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                                         10
# -                                                                                   200
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                                       210
# -                                                                                   200
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                                        300
# -                                                                                   200
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                                       150
# -                                                                                   300
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi                                     100
# -                                                                                   200
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                                       100
# -                                                                                     x
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                                       x
# -                                                                                     x
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi                                     300
# -                                                                                     x
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi                                      90
# -                                                                                   100
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                                     100
# -                                                                                   200
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                                     200
# -                                                                                     0
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                                      200
# -                                                                                   200
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                                     300
# -                                                                                   110
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                                      40
# -                                                                                   300
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                                     140
# -                                                                                   300
# EU_18387_14_1E_HandE.ndpi                                                           300
# -                                                                                   300
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                                        100
# -                                                                                   200
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi                                      20
# -                                                                                   300
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                                     100
# -                                                                                   300
#
#                                                 Any areas with complete absence of PTEN ? RESCORE BETTER STAINED TMA  \
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi                                                  X
# -                                                                                              NaN
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi                                                  x
# -                                                                                              NaN
# EU_2248_16_K_H&E.ndpi                                                                           no
# -                                                                                              NaN
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi                                                  yes
# -                                                                                              NaN
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi                                                 no
# -                                                                                              NaN
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi                                                  x
# -                                                                                                x
# EU_7189_16_2D_HandE.ndpi                                                                        no
# -                                                                                              NaN
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                                                      x
# -                                                                                              NaN
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                                                   yes
# -                                                                                              NaN
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                                                  yes
# -                                                                                              NaN
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                                                    no
# -                                                                                              NaN
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                                                   no
# -                                                                                              NaN
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi                                                 no
# -                                                                                              NaN
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                                                   no
# -                                                                                                x
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                                                  x
# -                                                                                                x
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi                                                 no
# -                                                                                                x
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi                                                yes
# -                                                                                              NaN
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                                                 no
# -                                                                                              NaN
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                                                 no
# -                                                                                              NaN
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                                                  no
# -                                                                                              NaN
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                                                 no
# -                                                                                              NaN
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                                                yes
# -                                                                                              NaN
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                                                 no
# -                                                                                              NaN
# EU_18387_14_1E_HandE.ndpi                                                                       no
# -                                                                                              NaN
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                                                    no
# -                                                                                              NaN
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi                                                yes
# -                                                                                              NaN
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                                                 no
# -                                                                                               no
#
#                                                 PTEN scoring comments RESCORE BETTER STAINED TMA
# file_name
# EU_29797_14_5F_HandE+-+2017-11-28+13.15.48.ndpi       No tumour to score - use original scorings
# -                                                                                            NaN
# EU_30831_14_4D_HandE+-+2017-11-28+11.15.23.ndpi                                        no tumour
# -                                                                                            NaN
# EU_2248_16_K_H&E.ndpi                                                                        NaN
# -                                                                                            NaN
# 17_A047-4519_1614P+-+2017-05-11+09.50.49.ndpi                                                NaN
# -                                                                                            NaN
# EU_37747_14_5S_HandE+-+2017-11-28+13.04.58.ndpi                                              NaN
# -                                                                                            NaN
# EU_49057_14_2F_HandE+-+2017-11-28+10.42.55.ndpi       No tumour to score - use original scorings
# -                                                                  drop out - use previous score
# EU_7189_16_2D_HandE.ndpi                                                                     NaN
# -                                                                                            NaN
# 17_A047-8544_16J+-+2017-05-11+08.49.27.ndpi                                   no tumour to score
# -                                                                                            NaN
# 17_A047-4463_153D+-+2017-05-11+09.40.22.ndpi                                                 NaN
# -                                                                                            NaN
# 17_A047-28956_156N+-+2017-05-11+09.57.53.ndpi                                                NaN
# -                                                                                            NaN
# 17_A047-10719_16L+-+2017-05-11+08.56.52.ndpi                                                 NaN
# -                                                                                            NaN
# 17_A047-19575_162E+-+2017-05-11+08.34.36.ndpi                                                NaN
# -                                                                                            NaN
# EU_29769_15_1M_HandE+-+2017-11-28+11.56.21.ndpi          only a couple of tumour glands to score
# -                                                                                            NaN
# 17_A047-29957_152D+-+2017-05-11+10.06.25.ndpi                                                NaN
# -                                                                                      drop out
# EU_26162_16_9x_HandE+-+2017-11-28+11.03.04.ndpi                                         drop out
# -                                                                                       drop out
# EU_29373_16_1G_HandE+-+2017-11-28+10.25.19.ndpi                                              NaN
# -                                                                                       drop out
# EU_35928_15_4N_HandE+-+2017-11-28+12.08.09.ndpi        a couple of glands are negatively stained
# -                                                                                            NaN
# EU_37106_15_2K_HandE+-+2017-11-28+11.43.55.ndpi                                              NaN
# -                                                                                            NaN
# EU_29542_16_1S_HandE+-+2017-11-28+12.49.46.ndpi                                              NaN
# -                                                                                            NaN
# EU_30479_16_G_HandE+-+2017-11-28+12.31.57.ndpi                                               NaN
# -                                                                                            NaN
# EU_42619_15_2H_HandE+-+2017-11-28+11.31.12.ndpi                                              NaN
# -                                                                                            NaN
# EU_42628_15_4J_HandE+-+2017-11-28+12.20.38.ndpi                                              NaN
# -                                                                                            NaN
# EU_38663_17_7G_HandE+-+2017-11-28+11.48.55.ndpi                                              NaN
# -                                                                                            NaN
# EU_18387_14_1E_HandE.ndpi                                                                    NaN
# -                                                                                            NaN
# 17_A047-47800_15J+-+2017-05-11+08.12.44.ndpi                                                 NaN
# -                                                                                            NaN
# EU_52005_15_2I_HandE+-+2017-11-28+11.23.02.ndpi                                              NaN
# -                                                                                            NaN
# EU_36244_16_9A_HandE+-+2017-11-28+12.41.47.ndpi                                              NaN
# -                                                                                            NaN
#
# [54 rows x 29 columns]

# %%
# pi
# PTEN
proliferation = labels['Proliferation index Mib-1 0-100% (only invasive tumour scored, not PIN or intraductal Ca or inflammatory cells. In the benign, only luminal ep cells scored)'].apply(lambda x: int(x) if x.isdigit() else 0)
proliferation = proliferation.iloc[0::2]  # remove benign samples from spreadseet
proliferation.index = [s[:-5] for s in proliferation.index]

# %%
# plot feature space against ERG:
colors = ['r', 'b', 'g', 'y']
for slide, pten_v in pten.iteritems():  # erg is a Series
    color_ = colors[int(pten_v)]
    try:
        slide_x = e.x.loc[slide]
        plt.scatter(slide_x.iloc[:, 0], slide_x.iloc[:, 1], color=color_)
    except KeyError:
        pass

# %%
# get gland examples manually ?

# %%
def get_examples(self, data_dir=None, n_examples=5, mpp=0.2):
    r"""This methods assumes that the dataframe's index corresponds to the bounding box of tissue elements
    :param n_examples: how many image examples to extract for image per cluster
    :param mpp:
    """
    if self.x is None or self.y is None:
        raise ValueError("Data has not been read / processed yet for cluster extraction")
    if data_dir is None:
        data_dir = Path(self.loaded_paths[0]).parents[2]
        assert (data_dir/'data').is_dir(), "data_dir should contain dir 'data'"
    self.clusters = np.unique(self.y)
    examples = []
    for i, cluster in enumerate(tqdm_notebook(self.clusters, desc='clusters')):
        x_cluster = self.x.iloc[(self.y == cluster).to_numpy().squeeze()]
        examples.append(dict())
        for subset_id in tqdm_notebook(self.x.index.levels[0], desc='subsets'):
            try:
                subset_path = next((data_dir/(subset_id + sfx)) for sfx in ['.ndpi', '.svs', '.dzi'])
            except StopIteration:
                raise ValueError(f"Data dir does not contain image for {subset_id}")
            examples[i][subset_id] = []
            opt = WSIReader.get_reader_options(include_path=False)
            reader = WSIReader(opt, subset_path)
            try:
                x_subset = x_cluster.loc[subset_id]
            except KeyError:
                continue
            sample = x_subset.sample(n=n_examples, replace=True)
            for bb_s, row in sample.iterrows():
                x, y, w, h = tuple(int(d) for d in bb_s.split('_'))
                image = np.array(reader.read_region((x, y), 0, (w, h)))  # changed level from None to 0 !!!
                if image.shape[2] == 4:  # assume 4 channels images are RGBA
                    image = color.rgba2rgb(image)
                if image.max() <= 1.0 and image.min() >= 0.0:
                    image = image * 255.0
                image = image.astype(np.uint8)
                examples[i][subset_id].append(image)
    return examples

# %%
examples = get_examples(e, n_examples=3)
# Out:
# HBox(children=(IntProgress(value=0, description='clusters', max=5, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='subsets', max=20, style=ProgressStyle(description_width='init…
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-5b46fdd3ac9c> in <module>
# ----> 1 examples = get_examples(e, n_examples=3)
#
# <ipython-input-19-98f7e2c8dfe4> in get_examples(self, data_dir, n_examples, mpp)
#      31                 image = np.array(reader.read_region((x, y), 0, (w, h)))  # changed level from None to 0 !!!
#      32                 if image.shape[2] == 4:  # assume 4 channels images are RGBA
# ---> 33                     image = color.rgba2rgb(image)
#      34                 if image.max() <= 1.0 and image.min() >= 0.0:
#      35                     image = image * 255.0
#
# AttributeError: 'str' object has no attribute 'rgba2rgb'

# %%
def save_examples_grid(self, save_dir, examples, image_size=512):
    r""""""
    save_dir = Path(save_dir)
    n_clusters = len(examples)
    n_subsets = len(examples[0])
    n_examples = len(next(iter(examples[0].values())))
    print(f"n subsets, clusters: {n_subsets}, {n_clusters}")
    for n in tqdm_notebook(range(n_examples)):
        grid = np.zeros((image_size * n_subsets, image_size * n_clusters, 3))
        if n == 0:
            print(f"Grid size: {grid.size}")
        for j, cluster_examples in enumerate(examples):
            for i, (subset_id, subset_examples) in enumerate(cluster_examples.items()):
                if len(subset_examples) >= n+1:
                    example = np.array(subset_examples[n])
                    max_dim = max(example.shape[:2])
                    padded = np.pad(example, (
                            (0, max(0, max_dim - example.shape[0])),
                            (0, max(0, max_dim - example.shape[1])),
                            (0, 0)
                        ), 'constant')
                    resized = transform.resize(padded, output_shape=(image_size,)*2)
                    resized = (resized * 255.0).astype(np.uint8)
                    grid[i*image_size:(i+1)*image_size, j*image_size:(j+1)*image_size] = resized
                    cv2.putText(grid, f'{j}', (j*image_size, i*image_size), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,)*3)
                else:
                    print(f"No examples for cluster {j} in slide {subset_id}")
                    cv2.putText(grid, 'NA', (j*image_size, i*image_size), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,)*3)
        if n_subsets > n_clusters * 2:
            first_half, second_half = grid[:image_size*n_subsets//2], grid[image_size*n_subsets//2:]
            grid = np.concatenate((first_half, second_half), axis=1)
        if n_clusters > n_subsets * 2:
            first_half, second_half = grid[:, :image_size*n_clusters//2], grid[:, image_size*n_clusters//2:]
            grid = np.concatenate((first_half, second_half), axis=1)
        imageio.imwrite(save_dir/f'grid{n}.png', grid)
    with open(save_dir/'details.json', 'w') as details:
        json.dump({
            'experiment_name': self.name,
            'files': list(examples[0].keys()),
        }, details)
    print("Done!")

# %%
save_examples_grid(e, '/well/rittscher/users/achatrian/temp', examples, image_size=128)
